# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import statistics
from plotly.subplots import make_subplots
from plotly.graph_objs.layout import YAxis,XAxis,Margin

from turtle import fillcolor
from numpy import size

# %%
## Data from processing

LISA_1_data = pd.read_csv('1-LISA/Acoustic_data_1_LISA.csv')
Traces_1_LISA = LISA_1_data['Trace number']
Def_1_LISA = LISA_1_data['Deformation sample']
Pvel_1_LISA = LISA_1_data['P vel']
Svel_1_LISA = LISA_1_data['S vel']
YM_1_LISA = LISA_1_data['YM sample']
Totaldef_1_LISA = LISA_1_data['Total deformation']
TotalP_1_LISA = LISA_1_data['Total P vel']
TotalS_1_LISA = LISA_1_data['Total S vel']
TotalYM_1_LISA = LISA_1_data['Total YM']
PR_1_LISA = LISA_1_data['Poissons ratio']
CP_1_LISA = LISA_1_data['CP']
Stress_1_LISA = LISA_1_data['Stress [MPa]']
Mean_1_LISA=LISA_1_data['Mean']
Max_1_LISA=LISA_1_data['Max']
Min_1_LISA=LISA_1_data['Min']
MeanVp_1_LISA=LISA_1_data['Mean_Vp']
MeanVs_1_LISA=LISA_1_data['Mean_Vs']
MeanPR_1_LISA=LISA_1_data['Mean PR']

LISA_8_data = pd.read_csv('8-LISA/Acoustic_data_8_LISA.csv')
Traces_8_LISA = LISA_8_data['Trace number']
Def_8_LISA = LISA_8_data['Deformation sample']
Pvel_8_LISA = LISA_8_data['P vel']
Svel_8_LISA = LISA_8_data['S vel']
YM_8_LISA = LISA_8_data['YM sample']
Totaldef_8_LISA = LISA_8_data['Total deformation']
TotalP_8_LISA = LISA_8_data['Total P vel']
TotalS_8_LISA = LISA_8_data['Total S vel']
TotalYM_8_LISA = LISA_8_data['Total YM']
PR_8_LISA = LISA_8_data['Poissons ratio']
CP_8_LISA = LISA_8_data['CP']
Stress_8_LISA = LISA_8_data['Stress [MPa]']


LISA_10_data = pd.read_csv('10-LISA/Acoustic_data_10_LISA.csv')
Traces_10_LISA = LISA_10_data['Trace number']
Def_10_LISA = LISA_10_data['Deformation sample']
Pvel_10_LISA = LISA_10_data['P vel']
Svel_10_LISA = LISA_10_data['S vel']
YM_10_LISA = LISA_10_data['YM sample']
Totaldef_10_LISA = LISA_10_data['Total deformation']
TotalP_10_LISA = LISA_10_data['Total P vel']
TotalS_10_LISA = LISA_10_data['Total S vel']
TotalYM_10_LISA = LISA_10_data['Total YM']
PR_10_LISA = LISA_10_data['Poissons ratio']
CP_10_LISA = LISA_10_data['CP']
Stress_10_LISA = LISA_10_data['Stress [MPa]']
Mean_10_LISA=LISA_10_data['Mean']
Max_10_LISA=LISA_10_data['Max']
Min_10_LISA=LISA_10_data['Min']
MeanVp_10_LISA=LISA_10_data['Mean_Vp']
MeanVs_10_LISA=LISA_10_data['Mean_Vs']
MeanPR_10_LISA=LISA_10_data['Mean PR']


LISA_11_data = pd.read_csv('11-LISA/Acoustic_data_11_LISA.csv')
Traces_11_LISA = LISA_11_data['Trace number']
Def_11_LISA = LISA_11_data['Deformation sample']
Pvel_11_LISA = LISA_11_data['P vel']
Svel_11_LISA = LISA_11_data['S vel']
YM_11_LISA = LISA_11_data['YM sample']
Totaldef_11_LISA = LISA_11_data['Total deformation']
TotalP_11_LISA = LISA_11_data['Total P vel']
TotalS_11_LISA = LISA_11_data['Total S vel']
TotalYM_11_LISA = LISA_11_data['Total YM']
PR_11_LISA = LISA_11_data['Poissons ratio']
CP_11_LISA = LISA_11_data['CP']
Stress_11_LISA = LISA_11_data['Stress [MPa]']
Mean_11_LISA=LISA_11_data['Mean']
Max_11_LISA=LISA_11_data['Max']
Min_11_LISA=LISA_11_data['Min']
MeanVp_11_LISA=LISA_11_data['Mean_Vp']
MeanVs_11_LISA=LISA_11_data['Mean_Vs']
MeanPR_11_LISA=LISA_11_data['Mean PR']


LISA_13_data = pd.read_csv('13-LISA/Acoustic_data_13_LISA.csv')
Traces_13_LISA = LISA_13_data['Trace number']
Def_13_LISA = LISA_13_data['Deformation sample']
Pvel_13_LISA = LISA_13_data['P vel']
Svel_13_LISA = LISA_13_data['S vel']
YM_13_LISA = LISA_13_data['YM sample']
Totaldef_13_LISA = LISA_13_data['Total deformation']
TotalP_13_LISA = LISA_13_data['Total P vel']
TotalS_13_LISA = LISA_13_data['Total S vel']
TotalYM_13_LISA = LISA_13_data['Total YM']
PR_13_LISA = LISA_13_data['Poissons ratio']
CP_13_LISA = LISA_13_data['CP']
Stress_13_LISA = LISA_13_data['Stress [MPa]']
Mean_13_LISA=LISA_13_data['Mean']
Max_13_LISA=LISA_13_data['Max']
Min_13_LISA=LISA_13_data['Min']
MeanVp_13_LISA=LISA_13_data['Mean_Vp']
MeanVs_13_LISA=LISA_13_data['Mean_Vs']
MeanPR_13_LISA=LISA_13_data['Mean PR']

# %%
## Data from processing

PB19_data = pd.read_csv('Acoustic_data_PB19.csv')
Traces_PB19 = PB19_data['Trace number']
Def_PB19 = PB19_data['Deformation sample']
Pvel_PB19 = PB19_data['P vel']
Svel_PB19 = PB19_data['S vel']
YM_PB19 = PB19_data['YM sample']
Totaldef_PB19 = PB19_data['Total deformation']
TotalP_PB19 = PB19_data['Total P vel']
TotalS_PB19 = PB19_data['Total S vel']
TotalYM_PB19 = PB19_data['Total YM']
PR_PB19 = PB19_data['Poissons ratio']
CP_PB19 = PB19_data['CP']
Stress_PB19 = PB19_data['Stress [MPa]']
Mean_PB19 = PB19_data['Mean']
Max_PB19 = PB19_data['Max']
Min_PB19 = PB19_data['Min']
MeanVp_PB19=PB19_data['Mean_Vp']
MeanVs_PB19=PB19_data['Mean_Vs']
MeanPR_PB19=PB19_data['Mean PR']


PB20_data = pd.read_csv('Acoustic_data_PB20.csv')
Traces_PB20 = PB20_data['Trace number']
Def_PB20 = PB20_data['Deformation sample']
Pvel_PB20 = PB20_data['P vel']
Svel_PB20 = PB20_data['S vel']
YM_PB20 = PB20_data['YM sample']
Totaldef_PB20 = PB20_data['Total deformation']
TotalP_PB20 = PB20_data['Total P vel']
TotalS_PB20 = PB20_data['Total S vel']
TotalYM_PB20 = PB20_data['Total YM']
PR_PB20 = PB20_data['Poissons ratio']
CP_PB20 = PB20_data['CP']
Stress_PB20 = PB20_data['Stress [MPa]']
Mean_PB20 = PB20_data['Mean']
Max_PB20 = PB20_data['Max']
Min_PB20 = PB20_data['Min']
MeanVp_PB20=PB20_data['Mean_Vp']
MeanVs_PB20=PB20_data['Mean_Vs']
MeanPR_PB20=PB20_data['Mean PR']


PB21_data = pd.read_csv('Acoustic_data_PB21.csv')
Traces_PB21 = PB21_data['Trace number']
Def_PB21 = PB21_data['Deformation sample']
Pvel_PB21 = PB21_data['P vel']
Svel_PB21 = PB21_data['S vel']
YM_PB21 = PB21_data['YM sample']
Totaldef_PB21 = PB21_data['Total deformation']
TotalP_PB21 = PB21_data['Total P vel']
TotalS_PB21 = PB21_data['Total S vel']
TotalYM_PB21 = PB21_data['Total YM']
PR_PB21 = PB21_data['Poissons ratio']
CP_PB21 = PB21_data['CP']
Stress_PB21 = PB21_data['Stress [MPa]']
Mean_PB21 = PB21_data['Mean']
Max_PB21 = PB21_data['Max']
Min_PB21 = PB21_data['Min']
MeanVp_PB21=PB21_data['Mean_Vp']
MeanVs_PB21=PB21_data['Mean_Vs']
MeanPR_PB21=PB21_data['Mean PR']

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])


## Experimental data
# Denmark
fig.add_trace(go.Scatter(x = Traces_1_LISA, y = Pvel_1_LISA,  mode='markers', marker_symbol='bowtie', name='Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_1_LISA, y = Svel_1_LISA,  mode='markers', marker_symbol='bowtie', name='Vs', marker=dict(color='red',size=10)))
fig.add_trace(go.Scatter(x = Traces_1_LISA, y = Stress_1_LISA,  mode='lines+markers', marker_symbol='cross', name='Stress', marker=dict(color='blue',size=10)), secondary_y=True)

# fig.add_trace(go.Scatter(x = Traces_1_LISA, y = TotalP_1_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_1_LISA, y = TotalS_1_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.update_layout(template="simple_white", autosize=False, width=1400, height=800,
    title="1 Vedsted-1",
    xaxis_title="Acoustic traces",
    yaxis_title="Wave Velocity (m/s)",
    yaxis2_title='Stress (MPa)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="bottom", x=0.93, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
fig.update_yaxes(range=[0,290], secondary_y=True)
fig.update_xaxes(range=[0,650])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False
fig.add_vline(x=76, line_width=3, line_color="fuchsia")
fig.add_vline(x=76, line_width=3, line_color="fuchsia")
fig.add_vline(x=143, line_width=3, line_color="fuchsia")
fig.add_vline(x=143, line_width=3, line_color="fuchsia")
fig.add_vline(x=216, line_width=3, line_color="fuchsia")
fig.add_vline(x=216, line_width=3, line_color="fuchsia")
fig.add_vline(x=308, line_width=3, line_color="fuchsia")
fig.add_vline(x=308, line_width=3, line_color="fuchsia")
fig.add_vline(x=397, line_width=3, line_color="fuchsia")
fig.add_vline(x=397, line_width=3, line_color="fuchsia")

fig.show()

# %%
# fig = make_subplots(specs=[[{"secondary_y": True}]])

# # fig.add_trace(go.Scatter(x = Traces_8_LISA, y = Pvel_8_LISA,  mode='markers', marker_symbol='bowtie', name='Vp', marker=dict(color='darkgreen',size=10)))
# # fig.add_trace(go.Scatter(x = Traces_8_LISA, y = Svel_8_LISA,  mode='markers', marker_symbol='bowtie', name='Vs', marker=dict(color='red',size=10)))


# fig.add_trace(go.Scatter(x = Traces_8_LISA, y = TotalP_8_LISA,  mode='markers', marker_symbol='bowtie', name='Vp', marker=dict(color='darkgreen',size=10)))
# fig.add_trace(go.Scatter(x = Traces_8_LISA, y = TotalS_8_LISA,  mode='markers', marker_symbol='bowtie', name='Vs', marker=dict(color='red',size=10)))

# fig.add_trace(go.Scatter(x = Traces_8_LISA, y = Stress_8_LISA,  mode='lines+markers', marker_symbol='cross', name='Stress', marker=dict(color='blue',size=10)), secondary_y=True)

# fig.update_layout(template="simple_white", autosize=False, width=1400, height=800,
#     title="8 Gassum-1",
#     xaxis_title="Acoustic traces",
#     yaxis_title="Wave Velocity (m/s)",
#     yaxis2_title='Stress (MPa)',
#     font=dict(
#         family="New Times Roman",
#         size=30,
#         color="Black"
#     ),
#     legend=dict(title=None, orientation='v', y=0.5, yanchor="bottom", x=0.93, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
# )

# # plotly manual axis adjustments
# fig.update_yaxes(range=[1900,4000], secondary_y=False)
# fig.update_yaxes(range=[0,290], secondary_y=True)
# fig.update_xaxes(range=[0,650])
# fig.update_yaxes(showgrid=True)
# fig.update_xaxes(showgrid=True)
# fig['layout']['yaxis']['showgrid'] = False
# fig.add_vline(x=62, line_width=3, line_color="fuchsia")
# fig.add_vline(x=62, line_width=3, line_color="fuchsia")
# fig.add_vline(x=111, line_width=3, line_color="fuchsia")
# fig.add_vline(x=111, line_width=3, line_color="fuchsia")
# fig.add_vline(x=172, line_width=3, line_color="fuchsia")
# fig.add_vline(x=172, line_width=3, line_color="fuchsia")
# fig.add_vline(x=234, line_width=3, line_color="fuchsia")
# fig.add_vline(x=234, line_width=3, line_color="fuchsia")

# fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x = Traces_10_LISA, y = Pvel_10_LISA,  mode='markers', marker_symbol='bowtie', name='Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_10_LISA, y = Svel_10_LISA,  mode='markers', marker_symbol='bowtie', name='Vs', marker=dict(color='red',size=10)))
fig.add_trace(go.Scatter(x = Traces_10_LISA, y = Stress_10_LISA,  mode='lines+markers', marker_symbol='cross', name='Stress', marker=dict(color='blue',size=10)), secondary_y=True)

# fig.add_trace(go.Scatter(x = Traces_10_LISA, y = TotalP_10_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_10_LISA, y = TotalS_10_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)

fig.update_layout(template="simple_white", autosize=False, width=1400, height=800,
    title="10 Gassum-1",
    xaxis_title="Acoustic traces",
    yaxis_title="Wave Velocity (m/s)",
    yaxis2_title='Stress (MPa)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="bottom", x=0.93, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
fig.update_yaxes(range=[0,290], secondary_y=True)
fig.update_xaxes(range=[0,650])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False
fig.add_vline(x=58, line_width=3, line_color="fuchsia")
fig.add_vline(x=58, line_width=3, line_color="fuchsia")
fig.add_vline(x=121, line_width=3, line_color="fuchsia")
fig.add_vline(x=121, line_width=3, line_color="fuchsia")
fig.add_vline(x=186, line_width=3, line_color="fuchsia")
fig.add_vline(x=186, line_width=3, line_color="fuchsia")
fig.add_vline(x=254, line_width=3, line_color="fuchsia")
fig.add_vline(x=254, line_width=3, line_color="fuchsia")
fig.add_vline(x=334, line_width=3, line_color="fuchsia")
fig.add_vline(x=334, line_width=3, line_color="fuchsia")

fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x = Traces_11_LISA, y = Pvel_11_LISA,  mode='markers', marker_symbol='bowtie', name='Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_11_LISA, y = Svel_11_LISA,  mode='markers', marker_symbol='bowtie', name='Vs', marker=dict(color='red',size=10)))
fig.add_trace(go.Scatter(x = Traces_11_LISA, y = Stress_11_LISA,  mode='lines+markers', marker_symbol='cross', name='Stress', marker=dict(color='blue',size=10)), secondary_y=True)

# fig.add_trace(go.Scatter(x = Traces_11_LISA, y = TotalP_11_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_11_LISA, y = TotalS_11_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)

fig.update_layout(template="simple_white", autosize=False, width=1400, height=800,
    title="11 Gassum-1",
    xaxis_title="Acoustic traces",
    yaxis_title="Wave Velocity (m/s)",
    yaxis2_title='Stress (MPa)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="bottom", x=0.93, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
fig.update_yaxes(range=[0,290], secondary_y=True)
fig.update_xaxes(range=[0,650])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False
fig.add_vline(x=63, line_width=3, line_color="fuchsia")
fig.add_vline(x=63, line_width=3, line_color="fuchsia")
fig.add_vline(x=121, line_width=3, line_color="fuchsia")
fig.add_vline(x=121, line_width=3, line_color="fuchsia")
fig.add_vline(x=188, line_width=3, line_color="fuchsia")
fig.add_vline(x=188, line_width=3, line_color="fuchsia")
fig.add_vline(x=257, line_width=3, line_color="fuchsia")
fig.add_vline(x=257, line_width=3, line_color="fuchsia")
fig.add_vline(x=331, line_width=3, line_color="fuchsia")
fig.add_vline(x=331, line_width=3, line_color="fuchsia")

fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x = Traces_13_LISA, y = Pvel_13_LISA,  mode='markers', marker_symbol='bowtie', name='Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_13_LISA, y = Svel_13_LISA,  mode='markers', marker_symbol='bowtie', name='Vs', marker=dict(color='red',size=10)))
fig.add_trace(go.Scatter(x = Traces_13_LISA, y = Stress_13_LISA,  mode='lines+markers', marker_symbol='cross', name='Stress', marker=dict(color='blue',size=10)), secondary_y=True)

# fig.add_trace(go.Scatter(x = Traces_13_LISA, y = TotalP_13_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_13_LISA, y = TotalS_13_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)

fig.update_layout(template="simple_white", autosize=False, width=1400, height=800,
    title="13 Stenlille-6",
    xaxis_title="Acoustic traces",
    yaxis_title="Wave Velocity (m/s)",
    yaxis2_title='Stress (MPa)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="bottom", x=0.93, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
fig.update_yaxes(range=[0,290], secondary_y=True)
fig.update_xaxes(range=[0,650])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False
fig.add_vline(x=54, line_width=3, line_color="fuchsia")
fig.add_vline(x=54, line_width=3, line_color="fuchsia")
fig.add_vline(x=144, line_width=3, line_color="fuchsia")
fig.add_vline(x=144, line_width=3, line_color="fuchsia")
fig.add_vline(x=260, line_width=3, line_color="fuchsia")
fig.add_vline(x=260, line_width=3, line_color="fuchsia")
fig.add_vline(x=369, line_width=3, line_color="fuchsia")
fig.add_vline(x=369, line_width=3, line_color="fuchsia")
fig.add_vline(x=482, line_width=3, line_color="fuchsia")
fig.add_vline(x=482, line_width=3, line_color="fuchsia")

fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])


## Experimental data

# Germany
fig.add_trace(go.Scatter(x = Traces_PB19, y = Pvel_PB19,  mode='markers', marker_symbol='cross', name='Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_PB19, y = Svel_PB19,  mode='markers', marker_symbol='cross', name='Vs', marker=dict(color='red',size=10)))
fig.add_trace(go.Scatter(x = Traces_PB19, y = Stress_PB19,  mode='lines+markers', marker_symbol='cross', name='Stress', marker=dict(color='blue',size=10)), secondary_y=True)

# fig.add_trace(go.Scatter(x = Traces_PB19, y = TotalP_PB19,  mode='lines+markers', marker_symbol='cross', name='Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_PB19, y = TotalS_PB19,  mode='lines+markers', marker_symbol='cross', name='Total Vs', marker=dict(color='orange',size=5)))


fig.update_layout(template="simple_white", autosize=False, width=1400, height=800,
    title="PB19",
    xaxis_title="Acoustic traces",
    yaxis_title="Wave Velocity (m/s)",
    yaxis2_title='Stress (MPa)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="bottom", x=0.93, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
fig.update_yaxes(range=[0,290], secondary_y=True)
fig.update_xaxes(range=[0,650])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False
fig.add_vline(x=52, line_width=3, line_color="fuchsia")
fig.add_vline(x=52, line_width=3, line_color="fuchsia")
fig.add_vline(x=154, line_width=3, line_color="fuchsia")
fig.add_vline(x=154, line_width=3, line_color="fuchsia")
fig.add_vline(x=277, line_width=3, line_color="fuchsia")
fig.add_vline(x=277, line_width=3, line_color="fuchsia")
fig.add_vline(x=422, line_width=3, line_color="fuchsia")
fig.add_vline(x=422, line_width=3, line_color="fuchsia")
fig.add_vline(x=578, line_width=3, line_color="fuchsia")
fig.add_vline(x=578, line_width=3, line_color="fuchsia")

fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x = Traces_PB20, y = Pvel_PB20,  mode='markers', marker_symbol='cross', name='Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_PB20, y = Svel_PB20,  mode='markers', marker_symbol='cross', name='Vs', marker=dict(color='red',size=10)))
fig.add_trace(go.Scatter(x = Traces_PB20, y = Stress_PB20,  mode='lines+markers', marker_symbol='cross', name='Stress', marker=dict(color='blue',size=10)), secondary_y=True)

# fig.add_trace(go.Scatter(x = Traces_PB20, y = TotalP_PB20,  mode='lines+markers', marker_symbol='cross', name='Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_PB20, y = TotalS_PB20,  mode='lines+markers', marker_symbol='cross', name='Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)

fig.update_layout(template="simple_white", autosize=False, width=1400, height=800,
    title="PB20",
    xaxis_title="Acoustic traces",
    yaxis_title="Wave Velocity (m/s)",
    yaxis2_title='Stress (MPa)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=.50, yanchor="bottom", x=0.93, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
fig.update_yaxes(range=[0,290], secondary_y=True, color='blue')
fig.update_xaxes(range=[0,650])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False
fig.add_vline(x=42, line_width=3, line_color="fuchsia")
fig.add_vline(x=42, line_width=3, line_color="fuchsia")
fig.add_vline(x=123, line_width=3, line_color="fuchsia")
fig.add_vline(x=123, line_width=3, line_color="fuchsia")
fig.add_vline(x=238, line_width=3, line_color="fuchsia")
fig.add_vline(x=238, line_width=3, line_color="fuchsia")
fig.add_vline(x=353, line_width=3, line_color="fuchsia")
fig.add_vline(x=353, line_width=3, line_color="fuchsia")
fig.add_vline(x=492, line_width=3, line_color="fuchsia")
fig.add_vline(x=492, line_width=3, line_color="fuchsia")

fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])

fig.add_trace(go.Scatter(x = Traces_PB21, y = Pvel_PB21,  mode='markers', marker_symbol='cross', name='Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_PB21, y = Svel_PB21,  mode='markers', marker_symbol='cross', name='Vs', marker=dict(color='red',size=10)))
fig.add_trace(go.Scatter(x = Traces_PB21, y = Stress_PB21,  mode='lines+markers', marker_symbol='cross', name='Stress', marker=dict(color='blue',size=10)), secondary_y=True)

# fig.add_trace(go.Scatter(x = Traces_PB21, y = TotalP_PB21,  mode='lines+markers', marker_symbol='cross', name='Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_PB21, y = TotalS_PB21,  mode='lines+markers', marker_symbol='cross', name='Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)

fig.update_layout(template="simple_white", autosize=False, width=1400, height=800,
    title="PB21",
    xaxis_title="Acoustic traces",
    yaxis_title="Wave Velocity (m/s)",
    yaxis2_title='Stress (MPa)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="bottom", x=0.93, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
fig.update_yaxes(range=[0,290], secondary_y=True)
fig.update_xaxes(range=[0,650])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False

# fig.update_yaxes(rangemode='tozero', scaleanchor='y', scaleratio=1, constraintoward='bottom', secondary_y=True)
# fig.update_yaxes(rangemode='tozero', scaleanchor='y2', scaleratio=0.1, constraintoward='bottom', secondary_y=False)
fig.add_vline(x=41, line_width=3, line_color="fuchsia")
fig.add_vline(x=41, line_width=3, line_color="fuchsia")
fig.add_vline(x=129, line_width=3, line_color="fuchsia")
fig.add_vline(x=129, line_width=3, line_color="fuchsia")
fig.add_vline(x=195, line_width=3, line_color="fuchsia")
fig.add_vline(x=195, line_width=3, line_color="fuchsia")
fig.add_vline(x=274, line_width=3, line_color="fuchsia")
fig.add_vline(x=274, line_width=3, line_color="fuchsia")
fig.add_vline(x=363, line_width=3, line_color="fuchsia")
fig.add_vline(x=363, line_width=3, line_color="fuchsia")

fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])


## Experimental data
# Denmark
fig.add_trace(go.Scatter(x = Traces_1_LISA, y = Pvel_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Vp', marker=dict(color='forestgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_1_LISA, y = Svel_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Vs', marker=dict(color='orangered',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = Traces_1_LISA, y = TotalP_1_LISA,  mode='lines+markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_1_LISA, y = TotalS_1_LISA,  mode='lines+markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Total Vs', marker=dict(color='orange',size=5)), secondary_y=False)


# fig.add_trace(go.Scatter(x = Traces_8_LISA, y = Pvel_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vp', marker=dict(color='blue',size=10)))
# fig.add_trace(go.Scatter(x = Traces_8_LISA, y = Svel_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vs', marker=dict(color='orange',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = Traces_8_LISA, y = TotalP_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vp', marker=dict(color='forestgreen',size=10)))
# fig.add_trace(go.Scatter(x = Traces_8_LISA, y = TotalS_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vs', marker=dict(color='salmon',size=10)), secondary_y=False)


fig.add_trace(go.Scatter(x = Traces_10_LISA, y = Pvel_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Vp', marker=dict(color='forestgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_10_LISA, y = Svel_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Vs', marker=dict(color='orangered',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = Traces_10_LISA, y = TotalP_10_LISA,  mode='lines+markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_10_LISA, y = TotalS_10_LISA,  mode='lines+markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Total Vs', marker=dict(color='orange',size=5)), secondary_y=False)


fig.add_trace(go.Scatter(x = Traces_11_LISA, y = Pvel_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Vp', marker=dict(color='forestgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_11_LISA, y = Svel_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Vs', marker=dict(color='orangered',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = Traces_11_LISA, y = TotalP_11_LISA,  mode='lines+markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_11_LISA, y = TotalS_11_LISA,  mode='lines+markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Total Vs', marker=dict(color='orange',size=5)), secondary_y=False)


fig.add_trace(go.Scatter(x = Traces_13_LISA, y = Pvel_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_13_LISA, y = Svel_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Vs', marker=dict(color='red',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = Traces_13_LISA, y = TotalP_13_LISA,  mode='lines+markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_13_LISA, y = TotalS_13_LISA,  mode='lines+markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Total Vs', marker=dict(color='orange',size=5)), secondary_y=False)


fig.update_layout(template="simple_white", autosize=False, width=1500, height=800,
    title="Danish samples",
    xaxis_title="Acoustic traces",
    yaxis_title="Wave Velocity (m/s)",
    yaxis2_title='S Velocity (m/s)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0, yanchor="bottom", x=0.9, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)


# fig.update_layout(legend_title_text = '<b>Danish samples<b>',
#                     legend_tracegroupgap= 10)
# fig.add_annotation(xref='paper', yref='paper',
#                         x=1.165, y=0.5,
#                         text='<b>German samples<b>',
#                         showarrow=False,
#                         font=dict(
#         family="New Times Roman",
#         size=20,
#         color="Black"
#     ))
# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
fig.update_xaxes(range=[0,650])
# fig.update_yaxes(range=[1350,4000], secondary_y=True)
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False
fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x = Traces_PB19, y = Pvel_PB19,  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB19 Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_PB19, y = Svel_PB19,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB19 Vs', marker=dict(color='red',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = Traces_PB19, y = TotalP_PB19,  mode='lines+markers', legendgroup="group1",  marker_symbol='cross', name='PB19 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_PB19, y = TotalS_PB19,  mode='lines+markers', legendgroup="group1",  marker_symbol='cross', name='PB19 Total Vs', marker=dict(color='orange',size=5)), secondary_y=False)


fig.add_trace(go.Scatter(x = Traces_PB20, y = Pvel_PB20,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_PB20, y = Svel_PB20,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Vs', marker=dict(color='red',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = Traces_PB20, y = TotalP_PB20,  mode='lines+markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_PB20, y = TotalS_PB20,  mode='lines+markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Total Vs', marker=dict(color='orange',size=5)), secondary_y=False)


fig.add_trace(go.Scatter(x = Traces_PB21, y = Pvel_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = Traces_PB21, y = Svel_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Vs', marker=dict(color='red',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = Traces_PB21, y = TotalP_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = Traces_PB21, y = TotalS_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Total Vs', marker=dict(color='orange',size=5)), secondary_y=False)


fig.update_layout(template="simple_white", showlegend=False, autosize=False, width=1500, height=800,
    title="German samples",
    xaxis_title="Acoustic traces",
    yaxis_title="Wave Velocity (m/s)",
    yaxis2_title='S Velocity (m/s)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0, yanchor="bottom", x=0.9, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)



fig.update_layout(legend_title_text = '<b>Danish samples<b>',
                    legend_tracegroupgap= 10)
# fig.add_annotation(xref='paper', yref='paper',
#                         x=1.165, y=0.5,
#                         text='<b>German samples<b>',
#                         showarrow=False,
#                         font=dict(
#         family="New Times Roman",
#         size=20,
#         color="Black"
#     ))
# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
fig.update_xaxes(range=[0,650])
# fig.update_yaxes(range=[1350,4000], secondary_y=True)
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False
fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])


## Experimental data
# Denmark
fig.add_trace(go.Scatter(x = CP_1_LISA, y = MeanVp_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Mean Vp', marker=dict(color='#1f78b4',size=15)))
fig.add_trace(go.Scatter(x = CP_1_LISA, y = MeanVs_1_LISA,  mode='markers', legendgroup="group1", marker_symbol='bowtie', name='1 Vedsted-1 Mean Vs', marker=dict(color='#008B8B',size=15)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_1_LISA, y = TotalP_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_1_LISA, y = TotalS_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Vs', marker=dict(color='orangered',size=10)), secondary_y=False)


# fig.add_trace(go.Scatter(x = CP_8_LISA, y = Pvel_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vp', marker=dict(color='blue',size=10)))
# fig.add_trace(go.Scatter(x = CP_8_LISA, y = Svel_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vs', marker=dict(color='orange',size=10)), secondary_y=True)

# fig.add_trace(go.Scatter(x = CP_8_LISA, y = TotalP_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vp', marker=dict(color='forestgreen',size=10)))
# fig.add_trace(go.Scatter(x = CP_8_LISA, y = TotalS_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vs', marker=dict(color='salmon',size=10)), secondary_y=False)


fig.add_trace(go.Scatter(x = CP_10_LISA, y = MeanVp_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Mean Vp', marker=dict(color='#B22222',size=15)))
fig.add_trace(go.Scatter(x = CP_10_LISA, y = MeanVs_10_LISA,  mode='markers', legendgroup="group1", marker_symbol='bowtie', name='10 Gassum-1 Mean Vs', marker=dict(color='#FF3030',size=15)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_10_LISA, y = TotalP_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_10_LISA, y = TotalS_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.add_trace(go.Scatter(x = CP_11_LISA, y = MeanVp_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Mean Vp', marker=dict(color='#8B0A50',size=15)))
fig.add_trace(go.Scatter(x = CP_11_LISA, y = MeanVs_11_LISA,  mode='markers', legendgroup="group1", marker_symbol='bowtie', name='11 Gassum-1 Mean Vs', marker=dict(color='#FF1493',size=15)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_11_LISA, y = TotalP_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_11_LISA, y = TotalS_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.add_trace(go.Scatter(x = CP_13_LISA, y = MeanVp_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Mean Vp', marker=dict(color='#00008B',size=15)))
fig.add_trace(go.Scatter(x = CP_13_LISA, y = MeanVs_13_LISA,  mode='markers', legendgroup="group1", marker_symbol='bowtie', name='13 Stenlille-6 Mean Vs', marker=dict(color='#0000FF',size=15)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_13_LISA, y = TotalP_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_13_LISA, y = TotalS_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.update_layout(template="simple_white", showlegend=True,autosize=False, width=1100, height=1100,
    title="Danish samples",
    xaxis_title="Confining Pressure (MPa)",
    yaxis_title="Wave Velocity (m/s)",
    # yaxis2_title='Confining Pressure ()',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="middle", x=1.2, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=0)
)

fig.update_layout(legend_title_text = '<b>Vp<b>',
                    legend_tracegroupgap= 300)
fig.add_annotation(xref='paper', yref='paper',
                        x=0.99, y=0.315,
                        text='<b>Vs<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=20,
        color="Black"
    ))
# plotly manual axis adjustments
fig.update_yaxes(range=[1400,4000], secondary_y=False)
# fig.update_yaxes(range=[1350,4000], secondary_y=True)
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
# fig['layout']['yaxis']['showgrid'] = False
fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])


## Experimental data

fig.add_trace(go.Scatter(x = CP_PB19, y = MeanVp_PB19,  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB19 Vp', marker=dict(color='#fb8072',size=15)))
fig.add_trace(go.Scatter(x = CP_PB19, y = MeanVs_PB19,  mode='markers', legendgroup="group2",  marker_symbol='cross', name='PB19 Vs', marker=dict(color='#fb8072',size=15)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_PB19, y = TotalP_PB19,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB19 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB19, y = TotalS_PB19,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB19 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.add_trace(go.Scatter(x = CP_PB20, y = MeanVp_PB20,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Vp', marker=dict(color='#b3de69',size=15)))
fig.add_trace(go.Scatter(x = CP_PB20, y = MeanVs_PB20,  mode='markers', legendgroup="group2",  marker_symbol='cross', name='PB20 Vs', marker=dict(color='#b3de69',size=15)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_PB20, y = TotalP_PB20,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB20, y = TotalS_PB20,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.add_trace(go.Scatter(x = CP_PB21, y = MeanVp_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Vp', marker=dict(color='#fccde5',size=15)))
fig.add_trace(go.Scatter(x = CP_PB21, y = MeanVs_PB21,  mode='markers', legendgroup="group2",  marker_symbol='cross', name='PB21 Vs', marker=dict(color='#fccde5',size=15)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_PB21, y = TotalP_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB21, y = TotalS_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.update_layout(template="simple_white", showlegend=True,autosize=False, width=1100, height=1100,
    title="German samples",
    xaxis_title="Confining Pressure (MPa)",
    yaxis_title="Wave Velocity (m/s)",
    # yaxis2_title='S Velocity (m/s)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.3, yanchor="bottom", x=1.03, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=0)
)


fig.update_layout(legend_title_text = '<b>Vp<b>',
                    legend_tracegroupgap= 400)
fig.add_annotation(xref='paper', yref='paper',
                        x=0.95, y=0.4,
                        text='<b>Vs<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=20,
        color="Black"
    ))
# plotly manual axis adjustments
fig.update_yaxes(range=[1400,4000], secondary_y=False)
# fig.update_yaxes(range=[1350,4000], secondary_y=True)
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
# fig['layout']['yaxis']['showgrid'] = False
fig.show()

# %%
CP_Norway = np.array([5, 10, 15])
T2461 = pd.read_csv('T2461_CID-data.csv')
MeanVp_T2461 = T2461['Mean_Vp']
MeanVs_T2461 = T2461['Mean_Vs']
T2463 = pd.read_csv('T2463_CID-data.csv')
MeanVp_T2463 = T2463['Mean_Vp']
MeanVs_T2463 = T2463['Mean_Vs']
T2464 = pd.read_csv('T2464_CID-data.csv')
MeanVp_T2464 = T2464['Mean_Vp']
MeanVs_T2464 = T2464['Mean_Vs']
T2466 = pd.read_csv('T2466_CID-data.csv')
MeanVp_T2466 = T2466['Mean_Vp']
MeanVs_T2466 = T2466['Mean_Vs']
T2467 = pd.read_csv('T2467_CID-data.csv')
MeanVp_T2467 = T2467['Mean_Vp']
MeanVs_T2467 = T2467['Mean_Vs']
T2469 = pd.read_csv('T2469_CID-data.csv')
MeanVp_T2469 = T2469['Mean_Vp']
MeanVs_T2469 = T2469['Mean_Vs']
T2470 = pd.read_csv('T2470_CID-data.csv')
MeanVp_T2470 = T2470['Mean_Vp']
MeanVs_T2470 = T2470['Mean_Vs']
T2472 = pd.read_csv('T2472_CID-data.csv')
MeanVp_T2472 = T2472['Mean_Vp']
MeanVs_T2472 = T2472['Mean_Vs']
T2476 = pd.read_csv('T2476_CID-data.csv')
MeanVp_T2476 = T2476['Mean_Vp']
MeanVs_T2476 = T2476['Mean_Vs']

fig = make_subplots(specs=[[{"secondary_y": True}]])


## Experimental data

fig.add_trace(go.Scatter(x = np.array(CP_Norway[0]), y = MeanVp_T2461,  mode='markers', legendgroup="group1", marker_symbol='triangle-up', name='T2461 Vp', marker=dict(color='cyan',size=15)))
fig.add_trace(go.Scatter(x = np.array(CP_Norway[0]), y = MeanVs_T2461,  mode='markers', legendgroup="group2",  marker_symbol='triangle-up', name='T2461 Vs', marker=dict(color='cyan',size=15)), secondary_y=False)

fig.add_trace(go.Scatter(x = np.array(CP_Norway[1]), y = MeanVp_T2463,  mode='markers', legendgroup="group1", marker_symbol='triangle-up', name='T2463 Vp', marker=dict(color='cyan',size=15)))
fig.add_trace(go.Scatter(x = np.array(CP_Norway[1]), y = MeanVs_T2463,  mode='markers', legendgroup="group2",  marker_symbol='triangle-up', name='T2463 Vs', marker=dict(color='cyan',size=15)), secondary_y=False)

fig.add_trace(go.Scatter(x = np.array(CP_Norway[2]), y = MeanVp_T2464,  mode='markers', legendgroup="group1", marker_symbol='triangle-up', name='T2464 Vp', marker=dict(color='cyan',size=15)))
fig.add_trace(go.Scatter(x = np.array(CP_Norway[2]), y = MeanVs_T2464,  mode='markers', legendgroup="group2",  marker_symbol='triangle-up', name='T2464 Vs', marker=dict(color='cyan',size=15)), secondary_y=False)

fig.add_trace(go.Scatter(x = np.array(CP_Norway[1]), y = MeanVp_T2467,  mode='markers', legendgroup="group1",  marker_symbol='triangle-up', name='T2467 Vp', marker=dict(color='fuchsia',size=15)))
fig.add_trace(go.Scatter(x = np.array(CP_Norway[1]), y = MeanVs_T2467,  mode='markers', legendgroup="group2",  marker_symbol='triangle-up', name='T2467 Vs', marker=dict(color='fuchsia',size=15)), secondary_y=False)

fig.add_trace(go.Scatter(x = np.array(CP_Norway[0]), y = MeanVp_T2466,  mode='markers', legendgroup="group1",  marker_symbol='triangle-up', name='T2466 Vp', marker=dict(color='fuchsia',size=15)))
fig.add_trace(go.Scatter(x = np.array(CP_Norway[0]), y = MeanVs_T2466,  mode='markers', legendgroup="group2",  marker_symbol='triangle-up', name='T2466 Vs', marker=dict(color='fuchsia',size=15)), secondary_y=False)

fig.add_trace(go.Scatter(x = np.array(CP_Norway[2]), y = MeanVp_T2469,  mode='markers', legendgroup="group1",  marker_symbol='triangle-up', name='T2469 Vp', marker=dict(color='fuchsia',size=15)))
fig.add_trace(go.Scatter(x = np.array(CP_Norway[2]), y = MeanVs_T2469,  mode='markers', legendgroup="group2",  marker_symbol='triangle-up', name='T2469 Vs', marker=dict(color='fuchsia',size=15)), secondary_y=False)


fig.add_trace(go.Scatter(x = np.array(CP_Norway[0]), y = MeanVp_T2470,  mode='markers', legendgroup="group1",  marker_symbol='triangle-up', name='T2470 Vp', marker=dict(color='lime',size=15)))
fig.add_trace(go.Scatter(x = np.array(CP_Norway[0]), y = MeanVs_T2470,  mode='markers', legendgroup="group2",  marker_symbol='triangle-up', name='T2470 Vs', marker=dict(color='lime',size=15)), secondary_y=False)

fig.add_trace(go.Scatter(x = np.array(CP_Norway[1]), y = MeanVp_T2472,  mode='markers', legendgroup="group1",  marker_symbol='triangle-up', name='T2472 Vp', marker=dict(color='lime',size=15)))
fig.add_trace(go.Scatter(x = np.array(CP_Norway[1]), y = MeanVs_T2472,  mode='markers', legendgroup="group2",  marker_symbol='triangle-up', name='T2472 Vs', marker=dict(color='lime',size=15)), secondary_y=False)

fig.add_trace(go.Scatter(x = np.array(CP_Norway[2]), y = MeanVp_T2476,  mode='markers', legendgroup="group1",  marker_symbol='triangle-up', name='T2476 Vp', marker=dict(color='lime',size=15)))
fig.add_trace(go.Scatter(x = np.array(CP_Norway[2]), y = MeanVs_T2476,  mode='markers', legendgroup="group2",  marker_symbol='triangle-up', name='T2476 Vs', marker=dict(color='lime',size=15)), secondary_y=False)

fig.update_layout(template="simple_white", showlegend=True,autosize=False, width=1100, height=1100,
    title="Norwegian samples",
    xaxis_title="Confining Pressure (MPa)",
    yaxis_title="Wave Velocity (m/s)",
    # yaxis2_title='S Velocity (m/s)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="middle", x=1.03, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=0)
)


fig.update_layout(legend_title_text = '<b>Vp<b>',
                    legend_tracegroupgap= 200)
fig.add_annotation(xref='paper', yref='paper',
                        x=0.94, y=0.39,
                        text='<b>Vs<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=25,
        color="Black"
    ))
# plotly manual axis adjustments
fig.update_yaxes(range=[1400,4000], secondary_y=False)
fig.update_xaxes(range=[0,50])
# fig.update_yaxes(range=[1350,4000], secondary_y=True)
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
# fig['layout']['yaxis']['showgrid'] = False
fig.show()

# %%
fig = make_subplots(specs=[[{"secondary_y": True}]])


## Experimental data
# Denmark
fig.add_trace(go.Scatter(x = CP_1_LISA, y = MeanVp_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Vp', marker=dict(color='forestgreen',size=10)))
fig.add_trace(go.Scatter(x = CP_1_LISA, y = MeanVs_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Vs', marker=dict(color='orangered',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_1_LISA, y = TotalP_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_1_LISA, y = TotalS_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1 Vs', marker=dict(color='orangered',size=10)), secondary_y=False)


# fig.add_trace(go.Scatter(x = CP_8_LISA, y = Pvel_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vp', marker=dict(color='blue',size=10)))
# fig.add_trace(go.Scatter(x = CP_8_LISA, y = Svel_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vs', marker=dict(color='orange',size=10)), secondary_y=True)

# fig.add_trace(go.Scatter(x = CP_8_LISA, y = TotalP_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vp', marker=dict(color='forestgreen',size=10)))
# fig.add_trace(go.Scatter(x = CP_8_LISA, y = TotalS_8_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='8 Gassum-1 Vs', marker=dict(color='salmon',size=10)), secondary_y=False)


fig.add_trace(go.Scatter(x = CP_10_LISA, y = MeanVp_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Vp', marker=dict(color='forestgreen',size=10)))
fig.add_trace(go.Scatter(x = CP_10_LISA, y = MeanVs_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Vs', marker=dict(color='orangered',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_10_LISA, y = TotalP_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_10_LISA, y = TotalS_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.add_trace(go.Scatter(x = CP_11_LISA, y = MeanVp_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Vp', marker=dict(color='forestgreen',size=10)))
fig.add_trace(go.Scatter(x = CP_11_LISA, y = MeanVs_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Vs', marker=dict(color='orangered',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_11_LISA, y = TotalP_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_11_LISA, y = TotalS_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.add_trace(go.Scatter(x = CP_13_LISA, y = MeanVp_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = CP_13_LISA, y = MeanVs_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Vs', marker=dict(color='red',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_13_LISA, y = TotalP_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_13_LISA, y = TotalS_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.add_trace(go.Scatter(x = CP_PB19, y = MeanVp_PB19,  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB19 Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = CP_PB19, y = MeanVs_PB19,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB19 Vs', marker=dict(color='red',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_PB19, y = TotalP_PB19,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB19 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB19, y = TotalS_PB19,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB19 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.add_trace(go.Scatter(x = CP_PB20, y = MeanVp_PB20,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = CP_PB20, y = MeanVs_PB20,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Vs', marker=dict(color='red',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_PB20, y = TotalP_PB20,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB20, y = TotalS_PB20,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB20 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.add_trace(go.Scatter(x = CP_PB21, y = MeanVp_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Vp', marker=dict(color='darkgreen',size=10)))
fig.add_trace(go.Scatter(x = CP_PB21, y = MeanVs_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Vs', marker=dict(color='red',size=10)), secondary_y=False)

# fig.add_trace(go.Scatter(x = CP_PB21, y = TotalP_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Total Vp', marker=dict(color='blue',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB21, y = TotalS_PB21,  mode='markers', legendgroup="group1",  marker_symbol='cross', name='PB21 Total Vs', marker=dict(color='orange',size=5)), secondary_y=True)


fig.update_layout(template="simple_white", showlegend=True,autosize=False, width=1100, height=1100,
    title="Wave velocities",
    xaxis_title="Confining Pressure (MPa)",
    yaxis_title="Wave Velocity (m/s)",
    # yaxis2_title='S Velocity (m/s)',
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="middle", x=1.2, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)


# fig.update_layout(legend_title_text = '<b>Danish samples<b>',
#                     legend_tracegroupgap= 10)
# fig.add_annotation(xref='paper', yref='paper',
#                         x=1.165, y=0.5,
#                         text='<b>German samples<b>',
#                         showarrow=False,
#                         font=dict(
#         family="New Times Roman",
#         size=20,
#         color="Black"
#     ))
# plotly manual axis adjustments
fig.update_yaxes(range=[1900,4000], secondary_y=False)
# fig.update_yaxes(range=[1350,4000], secondary_y=True)
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
# fig['layout']['yaxis']['showgrid'] = False
fig.show()

# %%
fig = go.Figure()

Danish_data = pd.read_csv('Danish_data.csv')
Sigma3 = np.array([10, 20, 30, 40, 50])
YoungM_1 = Danish_data['LISA_1_YM']
YoungM_8 = Danish_data['LISA_8_YM']
YoungM_9 = Danish_data['LISA_9_YM']
YoungM_10 = Danish_data['LISA_10_YM']
YoungM_11 = Danish_data['LISA_11_YM']
YoungM_12 = Danish_data['LISA_12_YM']
YoungM_13 = Danish_data['LISA_13_YM']

fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_1, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='1 Vedsted-1', marker=dict(color='#1f78b4',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_8, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='8 Gassum-1', marker=dict(color='#e31a1c',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_9, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='9 Gassum-1', marker=dict(color='#e31a1c',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_10, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='10 Gassum-1', marker=dict(color='#B22222',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_11, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='11 Gassum-1', marker=dict(color='#CD2626',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_13, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='13 Senlille-6', marker=dict(color='#00008B',size=15)))

fig.add_trace(go.Scatter(x = CP_1_LISA, y = YM_1_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='YM 1 Vedsted-1', marker=dict(color='#1f78b4',size=8)))
# fig.add_trace(go.Scatter(x = CP_8_LISA, y = YM_8_LISA,  mode='markers', legendgroup="group",  marker_symbol='bowtie', name='YM 8 Gassum-1', marker=dict(color='#e31a1c',size=15)))
fig.add_trace(go.Scatter(x = CP_10_LISA, y = YM_10_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='YM 10 Gassum-1', marker=dict(color='#B22222',size=8)))
fig.add_trace(go.Scatter(x = CP_11_LISA, y = YM_11_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='YM 11 Gassum-1', marker=dict(color='#CD2626',size=8)))
fig.add_trace(go.Scatter(x = CP_13_LISA, y = YM_13_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='YM 13 Stenlille-6', marker=dict(color='#00008B',size=8)))

# fig.add_trace(go.Scatter(x = CP_1_LISA, y = TotalYM_1_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 1 Vedsted-1', marker=dict(color='#1f78b4',size=5)))
# fig.add_trace(go.Scatter(x = CP_8_LISA, y = TotalYM_8_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 8 Gassum-1', marker=dict(color='#e31a1c',size=5)))
# fig.add_trace(go.Scatter(x = CP_10_LISA, y = TotalYM_10_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 10 Gassum-1', marker=dict(color='#B22222',size=5)))
# fig.add_trace(go.Scatter(x = CP_11_LISA, y = TotalYM_11_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 11 Gassum-1', marker=dict(color='#CD2626',size=5)))
# fig.add_trace(go.Scatter(x = CP_13_LISA, y = TotalYM_13_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 13 Stenlille-6', marker=dict(color='#00008B',size=5)))

fig.update_layout(template="simple_white", autosize=False, width=1100, height=1100,
    title="Danish samples",
    xaxis_title="Confining Pressure (MPa)",
    yaxis_title="Young's Modulus (GPa)",
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="middle", x=1.2, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)


fig.update_layout(legend_title_text = '<b>Static Youngs Modulus<b>',
                    legend_tracegroupgap= 30)
fig.add_annotation(xref='paper', yref='paper',
                        x=1.2, y=0.45,
                        text='<b>Dynamic Youngs Modulus<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=17,
        color="Black"
    ))

# fig.update_yaxes(range=[0,70])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False

fig.show()

# %%
fig = go.Figure()

Danish_data = pd.read_csv('Danish_data.csv')
Sigma3 = np.array([10, 20, 30, 40, 50])
YoungM_1 = Danish_data['LISA_1_YM']
YoungM_8 = Danish_data['LISA_8_YM']
YoungM_9 = Danish_data['LISA_9_YM']
YoungM_10 = Danish_data['LISA_10_YM']
YoungM_11 = Danish_data['LISA_11_YM']
YoungM_12 = Danish_data['LISA_12_YM']
YoungM_13 = Danish_data['LISA_13_YM']

fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_1, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='SYM 1 Vedsted-1', marker=dict(color='#1f78b4',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_8, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='SYM 8 Gassum-1', marker=dict(color='#e31a1c',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_9, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='SYM 9 Gassum-1', marker=dict(color='#e31a1c',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_10, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='SYM 10 Gassum-1', marker=dict(color='#B22222',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_11, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='SYM 11 Gassum-1', marker=dict(color='#CD2626',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_13, mode='markers', legendgroup="group3", marker_symbol='bowtie', name='SYM 13 Senlille-6', marker=dict(color='#00008B',size=15)))


# fig.add_trace(go.Scatter(x = CP_1_LISA, y = Max_1_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Max DYM 1 Vedsted-1', marker=dict(color='#1f78b4',size=20)))
# fig.add_trace(go.Scatter(x = CP_10_LISA, y = Max_10_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Max DYM 10 Gassum-1', marker=dict(color='#B22222',size=20)))
# fig.add_trace(go.Scatter(x = CP_11_LISA, y = Max_11_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Max DYM 11 Gassum-1', marker=dict(color='#CD2626',size=20)))
# fig.add_trace(go.Scatter(x = CP_13_LISA, y = Max_13_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Max DYM 13 Stenlille-6', marker=dict(color='#00008B',size=20)))

fig.add_trace(go.Scatter(x = CP_1_LISA, y = Mean_1_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Mean DYM 1 Vedsted-1', marker=dict(color='#1f78b4',size=15)))
fig.add_trace(go.Scatter(x = CP_10_LISA, y = Mean_10_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Mean DYM 10 Gassum-1', marker=dict(color='#B22222',size=15)))
fig.add_trace(go.Scatter(x = CP_11_LISA, y = Mean_11_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Mean DYM 11 Gassum-1', marker=dict(color='#CD2626',size=15)))
fig.add_trace(go.Scatter(x = CP_13_LISA, y = Mean_13_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Mean DYM 13 Stenlille-6', marker=dict(color='#00008B',size=15)))

# fig.add_trace(go.Scatter(x = CP_1_LISA, y = Min_1_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Min DYM 1 Vedsted-1', marker=dict(color='#1f78b4',size=10)))
# fig.add_trace(go.Scatter(x = CP_10_LISA, y = Min_10_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Min DYM 10 Gassum-1', marker=dict(color='#B22222',size=10)))
# fig.add_trace(go.Scatter(x = CP_11_LISA, y = Min_11_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Min DYM 11 Gassum-1', marker=dict(color='#CD2626',size=10)))
# fig.add_trace(go.Scatter(x = CP_13_LISA, y = Min_13_LISA,  mode='markers', legendgroup="group",  marker_symbol='star', name='Min DYM 13 Stenlille-6', marker=dict(color='#00008B',size=10)))

# fig.add_trace(go.Scatter(x = CP_1_LISA, y = TotalYM_1_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 1 Vedsted-1', marker=dict(color='#1f78b4',size=5)))
# fig.add_trace(go.Scatter(x = CP_8_LISA, y = TotalYM_8_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 8 Gassum-1', marker=dict(color='#e31a1c',size=5)))
# fig.add_trace(go.Scatter(x = CP_10_LISA, y = TotalYM_10_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 10 Gassum-1', marker=dict(color='#B22222',size=5)))
# fig.add_trace(go.Scatter(x = CP_11_LISA, y = TotalYM_11_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 11 Gassum-1', marker=dict(color='#CD2626',size=5)))
# fig.add_trace(go.Scatter(x = CP_13_LISA, y = TotalYM_13_LISA,  mode='lines+markers', marker_symbol='bowtie', name='Total YM 13 Stenlille-6', marker=dict(color='#00008B',size=5)))

fig.update_layout(template="simple_white", autosize=False, width=1100, height=1100,
    title="Danish samples",
    xaxis_title="Confining Pressure (MPa)",
    yaxis_title="Young's Modulus (GPa)",
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="middle", x=1.25, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)


fig.update_layout(legend_title_text = '<b>Static Youngs Modulus<b>',
                    legend_tracegroupgap= 30)
fig.add_annotation(xref='paper', yref='paper',
                        x=1.25, y=0.454,
                        text='<b>Dynamic Youngs Modulus<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=19,
        color="Black"
    ))

fig.update_yaxes(range=[0,40])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
# fig['layout']['yaxis']['showgrid'] = False

fig.show()

# %%
fig = go.Figure()
Sigma3 = np.array([10, 20, 30, 40, 50])
YoungM_PB2 = np.array([14.7])
YoungM_PB3 = np.array([16.5])
YoungM_PB15 = np.array([9.1])
YoungM_PB16 = np.array([9.05])
YoungM_PB18 = np.array([9.5])
YoungM_PB4 = np.array([22.9, 27.75, 28.3, 28.4])
YoungM_PB5 = np.array([21.3, 26.6, 26.5, 27, 25.9])
YoungM_PB6 = np.array([26.2, 27.6, 27.3, 27.1, 26.7])
YoungM_PB19 = np.array([16.1, 20, 21.65, 21.4, 21.9])
YoungM_PB20 = np.array([17.5, 22.6, 22.75, 23.9, 24.1])
YoungM_PB21 = np.array([17.3, 21.7, 22.5, 22.9, 23.3])
# Germany
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB2, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB2 - UCS', marker=dict(color='#ffed6f',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB5, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB5', marker=dict(color='#ffed6f',size=15)))
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB3, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB3 - UCS', marker=dict(color='#bebada',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB6, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB6', marker=dict(color='#bebada',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB4, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB4', marker=dict(color='#8dd3c7',size=15)))
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB15, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB15 - UCS', marker=dict(color='#fb8072',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB19, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB19', marker=dict(color='#fb8072',size=15)))
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB16, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB16 - UCS', marker=dict(color='#b3de69',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB20, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB20', marker=dict(color='#b3de69',size=15)))
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB18, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB18 - UCS', marker=dict(color='#fccde5',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB21, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB21', marker=dict(color='#fccde5',size=15)))

fig.add_trace(go.Scatter(x = CP_PB19, y = YM_PB19,  mode='markers', legendgroup="group", marker_symbol='cross', name='YM PB19', marker=dict(color='#fb8072',size=10)))
fig.add_trace(go.Scatter(x = CP_PB20, y = YM_PB20,  mode='markers', legendgroup="group",  marker_symbol='cross', name='YM PB20', marker=dict(color='#b3de69',size=10)))
fig.add_trace(go.Scatter(x = CP_PB21, y = YM_PB21,  mode='markers', legendgroup="group",  marker_symbol='cross', name='YM PB21', marker=dict(color='#fccde5',size=10)))

# Norway
# fig.add_trace(go.Scatter(x = np.array(4.95280721327762), y = np.array(6.19020964795148), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2461', marker=dict(color='cyan',size=15)))
# fig.add_trace(go.Scatter(x = np.array(9.95840754335207), y = np.array(8.89442542490185), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2463', marker=dict(color='cyan',size=15)))
# fig.add_trace(go.Scatter(x = np.array(14.9425571410644), y = np.array(9.8505967711706), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2464', marker=dict(color='cyan',size=15)))
# fig.add_trace(go.Scatter(x = np.array(4.97030623402618), y = np.array(6.89943834522109), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2466', marker=dict(color='fuchsia',size=15)))
# fig.add_trace(go.Scatter(x = np.array(9.97124662979295), y = np.array(9.48724271402332), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2467', marker=dict(color='fuchsia',size=15)))
# fig.add_trace(go.Scatter(x = np.array(14.9736347783681), y = np.array(10.472512403918), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2469', marker=dict(color='fuchsia',size=15)))
# fig.add_trace(go.Scatter(x = np.array(4.98991520650039), y = np.array(15.9042519867918), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2470', marker=dict(color='lime',size=15)))
# fig.add_trace(go.Scatter(x = np.array(9.98108621749613), y = np.array(17.2006701104299), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2472', marker=dict(color='lime',size=15)))
# fig.add_trace(go.Scatter(x = np.array(14.9846624439422), y = np.array(18.2118043148579), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2476', marker=dict(color='lime',size=15)))

# # ## Data from papers
# fig.add_trace(go.Scatter(x = np.array(21), y = np.array(7.5), mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Rotliegend G. DE (Haug,C.)', marker=dict(color='#9e0142',size=15)))
# fig.add_trace(go.Scatter(x = np.array(10.5), y = np.array(26),  mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Rotliegend G. NL (Orlic, B.)', marker=dict(color='#5e4fa2',size=15)))
# fig.add_trace(go.Scatter(x = np.array(11.1), y = np.array(18),  mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Rotliegend G. NL (Orlic, B.)', marker=dict(color='#006837',size=15)))
# fig.add_trace(go.Scatter(x = np.array(40), y = np.array(15.9),  mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Rotliegend G. NL (Schutte)', marker=dict(color='#542788',size=15)))
# fig.add_trace(go.Scatter(x = np.array(17.5), y = np.array(16.2),  mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Captain Fm. UK (Shell)', marker=dict(color='#7f3b08',size=15)))
# fig.add_trace(go.Scatter(x = CP_PB19, y = TotalYM_PB19,  mode='lines+markers', marker_symbol='cross', name='Total YM PB19', marker=dict(color='#fb8072',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB20, y = TotalYM_PB20,  mode='lines+markers', marker_symbol='cross', name='Total YM PB20', marker=dict(color='#b3de69',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB21, y = TotalYM_PB21,  mode='lines+markers', marker_symbol='cross', name='Total YM PB21', marker=dict(color='#fccde5',size=5)))

fig.update_layout(template="simple_white", autosize=False, width=1100, height=1100,
    # title="",
    xaxis_title="Confining Pressure (MPa)",
    yaxis_title="Young's Modulus (GPa)",
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="middle", x=1.25, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

fig.update_layout(legend_title_text = '<b>Static Youngs Modulus<b>',
                    legend_tracegroupgap= 30)
fig.add_annotation(xref='paper', yref='paper',
                        x=1.24, y=0.375,
                        text='<b>Dyn. Youngs Modulus<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=19,
        color="Black"
    ))

fig.update_yaxes(range=[0,40])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
# fig['layout']['yaxis']['showgrid'] = False

fig.show()

# %%
fig = go.Figure()
Sigma3 = np.array([10, 20, 30, 40, 50])
YoungM_PB2 = np.array([14.7])
YoungM_PB3 = np.array([16.5])
YoungM_PB15 = np.array([9.1])
YoungM_PB16 = np.array([9.05])
YoungM_PB18 = np.array([9.5])
YoungM_PB4 = np.array([22.9, 27.75, 28.3, 28.4])
YoungM_PB5 = np.array([21.3, 26.6, 26.5, 27, 25.9])
YoungM_PB6 = np.array([26.2, 27.6, 27.3, 27.1, 26.7])
YoungM_PB19 = np.array([16.1, 20, 21.65, 21.4, 21.9])
YoungM_PB20 = np.array([17.5, 22.6, 22.75, 23.9, 24.1])
YoungM_PB21 = np.array([17.3, 21.7, 22.5, 22.9, 23.3])
# Germany
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB2, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB2 - UCS', marker=dict(color='#ffed6f',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB5, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB5', marker=dict(color='#ffed6f',size=15)))
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB3, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB3 - UCS', marker=dict(color='#bebada',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB6, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB6', marker=dict(color='#bebada',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB4, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB4', marker=dict(color='#8dd3c7',size=15)))
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB15, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB15 - UCS', marker=dict(color='#fb8072',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB19, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB19', marker=dict(color='#fb8072',size=15)))
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB16, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB16 - UCS', marker=dict(color='#b3de69',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB20, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB20', marker=dict(color='#b3de69',size=15)))
fig.add_trace(go.Scatter(x = np.array(0), y = YoungM_PB18, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB18 - UCS', marker=dict(color='#fccde5',size=15)))
fig.add_trace(go.Scatter(x = Sigma3, y = YoungM_PB21, mode='markers', legendgroup="group2", marker_symbol='cross', name='PB21', marker=dict(color='#fccde5',size=15)))

fig.add_trace(go.Scatter(x = CP_PB19, y = Mean_PB19,  mode='markers', legendgroup="group", marker_symbol='star', name='Mean DYM PB19', marker=dict(color='#fb8072',size=15)))
fig.add_trace(go.Scatter(x = CP_PB20, y = Mean_PB20,  mode='markers', legendgroup="group",  marker_symbol='star', name='Mean DYM PB20', marker=dict(color='#b3de69',size=15)))
fig.add_trace(go.Scatter(x = CP_PB21, y = Mean_PB21,  mode='markers', legendgroup="group",  marker_symbol='star', name='Mean DYM PB21', marker=dict(color='#fccde5',size=15)))

# Norway
# fig.add_trace(go.Scatter(x = np.array(4.95280721327762), y = np.array(6.19020964795148), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2461', marker=dict(color='cyan',size=15)))
# fig.add_trace(go.Scatter(x = np.array(9.95840754335207), y = np.array(8.89442542490185), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2463', marker=dict(color='cyan',size=15)))
# fig.add_trace(go.Scatter(x = np.array(14.9425571410644), y = np.array(9.8505967711706), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2464', marker=dict(color='cyan',size=15)))
# fig.add_trace(go.Scatter(x = np.array(4.97030623402618), y = np.array(6.89943834522109), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2466', marker=dict(color='fuchsia',size=15)))
# fig.add_trace(go.Scatter(x = np.array(9.97124662979295), y = np.array(9.48724271402332), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2467', marker=dict(color='fuchsia',size=15)))
# fig.add_trace(go.Scatter(x = np.array(14.9736347783681), y = np.array(10.472512403918), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2469', marker=dict(color='fuchsia',size=15)))
# fig.add_trace(go.Scatter(x = np.array(4.98991520650039), y = np.array(15.9042519867918), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2470', marker=dict(color='lime',size=15)))
# fig.add_trace(go.Scatter(x = np.array(9.98108621749613), y = np.array(17.2006701104299), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2472', marker=dict(color='lime',size=15)))
# fig.add_trace(go.Scatter(x = np.array(14.9846624439422), y = np.array(18.2118043148579), mode='markers', legendgroup="group4", marker_symbol='triangle-up', name='T2476', marker=dict(color='lime',size=15)))

# # ## Data from papers
# fig.add_trace(go.Scatter(x = np.array(21), y = np.array(7.5), mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Rotliegend G. DE (Haug,C.)', marker=dict(color='#9e0142',size=15)))
# fig.add_trace(go.Scatter(x = np.array(10.5), y = np.array(26),  mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Rotliegend G. NL (Orlic, B.)', marker=dict(color='#5e4fa2',size=15)))
# fig.add_trace(go.Scatter(x = np.array(11.1), y = np.array(18),  mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Rotliegend G. NL (Orlic, B.)', marker=dict(color='#006837',size=15)))
# fig.add_trace(go.Scatter(x = np.array(40), y = np.array(15.9),  mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Rotliegend G. NL (Schutte)', marker=dict(color='#542788',size=15)))
# fig.add_trace(go.Scatter(x = np.array(17.5), y = np.array(16.2),  mode='markers', legendgroup="group5", marker_symbol='circle-x-open', name='Captain Fm. UK (Shell)', marker=dict(color='#7f3b08',size=15)))
# fig.add_trace(go.Scatter(x = CP_PB19, y = TotalYM_PB19,  mode='lines+markers', marker_symbol='cross', name='Total YM PB19', marker=dict(color='#fb8072',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB20, y = TotalYM_PB20,  mode='lines+markers', marker_symbol='cross', name='Total YM PB20', marker=dict(color='#b3de69',size=5)))
# fig.add_trace(go.Scatter(x = CP_PB21, y = TotalYM_PB21,  mode='lines+markers', marker_symbol='cross', name='Total YM PB21', marker=dict(color='#fccde5',size=5)))

fig.update_layout(template="simple_white", autosize=False, width=1100, height=1100,
    title="German samples",
    xaxis_title="Confining Pressure (MPa)",
    yaxis_title="Young's Modulus (GPa)",
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="middle", x=1.25, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

fig.update_layout(legend_title_text = '<b>Static Youngs Modulus<b>',
                    legend_tracegroupgap= 30)
fig.add_annotation(xref='paper', yref='paper',
                        x=1.24, y=0.375,
                        text='<b>Dyn. Youngs Modulus<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=19,
        color="Black"
    ))

fig.update_yaxes(range=[0,40])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
# fig['layout']['yaxis']['showgrid'] = False

fig.show()

# %%
fig = go.Figure()


fig.add_trace(go.Scatter(x = np.array(0), y = np.array(0.190430270635906),  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB2 UCS', marker=dict(color='#ffed6f',size=10)))
fig.add_trace(go.Scatter(x = np.array(0), y = np.array(0.289694068418007),  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB3 UCS', marker=dict(color='#bebada',size=10)))
fig.add_trace(go.Scatter(x = np.array(0), y = np.array(0.402153344722666),  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB15 UCS', marker=dict(color='#fb8072',size=10)))
fig.add_trace(go.Scatter(x = CP_PB19, y = MeanPR_PB19,  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB19', marker=dict(color='#fb8072',size=10)))
fig.add_trace(go.Scatter(x = np.array(0), y = np.array(0.317166225082323),  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB16 UCS', marker=dict(color='#b3de69',size=10)))
fig.add_trace(go.Scatter(x = CP_PB20, y = MeanPR_PB20,  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB20', marker=dict(color='#b3de69',size=10)))
fig.add_trace(go.Scatter(x = np.array(0), y = np.array(0.307157465319908),  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB18 UCS', marker=dict(color='#fccde5',size=10)))
fig.add_trace(go.Scatter(x = CP_PB21, y = MeanPR_PB21,  mode='markers', legendgroup="group1", marker_symbol='cross', name='PB21', marker=dict(color='#fccde5',size=10)))

fig.add_trace(go.Scatter(x = CP_1_LISA, y = MeanPR_1_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='1 Vedsted-1', marker=dict(color='#1f78b4',size=10)))
# fig.add_trace(go.Scatter(x = CP_8_LISA, y = MeanPR_8_LISA,  mode='markers', marker_symbol='bowtie', name='8 Gassum-1', marker=dict(color='#e31a1c',size=10)))
fig.add_trace(go.Scatter(x = CP_10_LISA, y = MeanPR_10_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='10 Gassum-1', marker=dict(color='#B22222',size=10)))
fig.add_trace(go.Scatter(x = CP_11_LISA, y = MeanPR_11_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='11 Gassum-1', marker=dict(color='#CD2626',size=10)))
fig.add_trace(go.Scatter(x = CP_13_LISA, y = MeanPR_13_LISA,  mode='markers', legendgroup="group", marker_symbol='bowtie', name='13 Stenlille-6', marker=dict(color='#00008B',size=10)))


fig.add_trace(go.Scatter(x = np.array(4.95280721327762), y = np.array(0.316592608676275),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2461', marker=dict(color='cyan',size=10)))
fig.add_trace(go.Scatter(x = np.array(9.95840754335207), y = np.array(0.245263894769999),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2463', marker=dict(color='cyan',size=10)))
fig.add_trace(go.Scatter(x = np.array(14.9425571410644), y = np.array(0.23544281294853),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2464', marker=dict(color='cyan',size=10)))
fig.add_trace(go.Scatter(x = np.array(4.97030623402618), y = np.array(0.289161722383495),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2466', marker=dict(color='fuchsia',size=10)))
fig.add_trace(go.Scatter(x = np.array(9.97124662979295), y = np.array(0.243893929449052),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2467', marker=dict(color='fuchsia',size=10)))
fig.add_trace(go.Scatter(x = np.array(14.9736347783681), y = np.array(0.24903070492309),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2469', marker=dict(color='fuchsia',size=10)))
fig.add_trace(go.Scatter(x = np.array(4.98991520650039), y = np.array(0.397342441209892),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2470', marker=dict(color='lime',size=10)))
fig.add_trace(go.Scatter(x = np.array(9.98108621749613), y = np.array(0.380045231561907),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2472', marker=dict(color='lime',size=10)))
fig.add_trace(go.Scatter(x = np.array(14.9846624439422), y = np.array(0.363889370104412),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2476', marker=dict(color='lime',size=10)))

fig.update_layout(template="simple_white", autosize=False, width=1100, height=1100,
    # title="PB21",
    xaxis_title="Confining Pressure (MPa)",
    yaxis_title="Poisson's Ratio (-)",
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="middle", x=1.2, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=1)
)

fig.update_layout(legend_title_text = '<b>German samples      <b>',
                    legend_tracegroupgap= 30)
fig.add_annotation(xref='paper', yref='paper',
                        x=1.15, y=0.56,
                        text='<b>Danish samples<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=19,
        color="Black"
    ))
fig.add_annotation(xref='paper', yref='paper',
                        x=1.19, y=0.425,
                        text='<b>Norwegian samples<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=19,
        color="Black"
    ))

fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig['layout']['yaxis']['showgrid'] = False

fig.show()

# %%
from turtle import fillcolor
from numpy import size
TNO_data = pd.read_csv('Sandstone_TNO.csv')

TVDSS_TNO = TNO_data['TVDSS Bottom (m)']
YM_TNO = TNO_data['Young Modulus E (GPa)']


fig = go.Figure()

#TNO
fig.add_trace(go.Scatter(x = YM_TNO, y = TVDSS_TNO,  mode='markers', legendgroup="group5", marker_symbol='circle', name='Sandstones', marker=dict(color='coral',size=7)))

## Experimental data
# Netherlands
# fig.add_trace(go.Scatter(x = np.array(K15_2_2V_YM[0]), y = np.array(3457.85),  mode='markers', marker_symbol='circle', name='1 Vedsted-1', marker=dict(color='#1f78b4',size=15)))      # For the danish samples the first value with a CP of 10 is more realistic for the depths of extraction
# fig.add_trace(go.Scatter(x = np.array(K15_2_6V_YM[0]), y = np.array(3461.9),  mode='markers', marker_symbol='circle', name='1 Vedsted-1', marker=dict(color='#1f78b4',size=15)))      # For the danish samples the first value with a CP of 10 is more realistic for the depths of extraction
# fig.add_trace(go.Scatter(x = np.array(K15_15A_10V_YM[0]), y = np.array(4237.83),  mode='markers', marker_symbol='circle', name='1 Vedsted-1', marker=dict(color='#1f78b4',size=15)))      # For the danish samples the first value with a CP of 10 is more realistic for the depths of extraction

# Germany
fig.add_trace(go.Scatter(y = np.array(0), x = YoungM_PB2, mode='markers', legendgroup="group", marker_symbol='cross', name='PB2 - UCS', marker=dict(color='#ffed6f',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_PB5[0]), y = np.array(1166.66), mode='markers', legendgroup="group", marker_symbol='cross', name='PB5', marker=dict(color='#ffed6f',size=15)))
fig.add_trace(go.Scatter(y = np.array(0), x = YoungM_PB3, mode='markers', legendgroup="group", marker_symbol='cross', name='PB3 - UCS', marker=dict(color='#bebada',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_PB6[0]), y = np.array(1166.66), mode='markers', legendgroup="group", marker_symbol='cross', name='PB6', marker=dict(color='#bebada',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_PB4[0]), y = np.array(1166.66), mode='markers', legendgroup="group", marker_symbol='cross', name='PB4', marker=dict(color='#8dd3c7',size=15)))
fig.add_trace(go.Scatter(y = np.array(0), x = YoungM_PB15, mode='markers', legendgroup="group", marker_symbol='cross', name='PB15 - UCS', marker=dict(color='#fb8072',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_PB19[0]), y = np.array(1166.66), mode='markers', legendgroup="group", marker_symbol='cross', name='PB19', marker=dict(color='#fb8072',size=15)))
fig.add_trace(go.Scatter(y = np.array(0), x = YoungM_PB16, mode='markers', legendgroup="group", marker_symbol='cross', name='PB16 - UCS', marker=dict(color='#b3de69',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_PB20[0]), y = np.array(1166.66), mode='markers', legendgroup="group", marker_symbol='cross', name='PB20', marker=dict(color='#b3de69',size=15)))
fig.add_trace(go.Scatter(y = np.array(0), x = YoungM_PB18, mode='markers', legendgroup="group", marker_symbol='cross', name='PB18 - UCS', marker=dict(color='#fccde5',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_PB21[0]), y = np.array(1166.66), mode='markers', legendgroup="group", marker_symbol='cross', name='PB21', marker=dict(color='#fccde5',size=15)))
fig.add_trace(go.Scatter(y = np.array(1166.66), x = Mean_PB19,  mode='markers', legendgroup="group", marker_symbol='star', name='Mean DYM PB19', marker=dict(color='#fb8072',size=15)))
fig.add_trace(go.Scatter(y = np.array(1166.66), x = Mean_PB20,  mode='markers', legendgroup="group",  marker_symbol='star', name='Mean DYM PB20', marker=dict(color='#b3de69',size=15)))
fig.add_trace(go.Scatter(y = np.array(1166.66), x = Mean_PB21,  mode='markers', legendgroup="group",  marker_symbol='star', name='Mean DYM PB21', marker=dict(color='#fccde5',size=15)))

# Denmark
fig.add_trace(go.Scatter(x = np.array(YoungM_1[0]), y = np.array(1776.67),  mode='markers', legendgroup="group2", marker_symbol='bowtie', name='1 Vedsted-1', marker=dict(color='#1f78b4',size=15)))      # For the danish samples the first value with a CP of 10 is more realistic for the depths of extraction
fig.add_trace(go.Scatter(x = np.array(YoungM_8[0]), y = np.array(1634.6),  mode='markers', legendgroup="group2", marker_symbol='bowtie', name='8 Gassum-1', marker=dict(color='#e31a1c',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_9[0]), y = np.array(1633),  mode='markers', legendgroup="group2", marker_symbol='bowtie', name='9 Gassum-1', marker=dict(color='#e31a1c',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_10[0]), y = np.array(1536.2),  mode='markers', legendgroup="group2", marker_symbol='bowtie', name='10 Gassum-1', marker=dict(color='#B22222',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_11[0]), y = np.array(1534.5),  mode='markers', legendgroup="group2", marker_symbol='bowtie', name='11 Gassum-1', marker=dict(color='#CD2626',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_12[0]), y = np.array(1582.7),  mode='markers', legendgroup="group2", marker_symbol='bowtie', name='12 Stenlille-6', marker=dict(color='royalblue',size=15)))
fig.add_trace(go.Scatter(x = np.array(YoungM_13[0]), y = np.array(1574.7),  mode='markers', legendgroup="group2", marker_symbol='bowtie', name='13 Stenlille-6', marker=dict(color='#00008B',size=15)))
fig.add_trace(go.Scatter(y = np.array(1776.67), x = Mean_1_LISA,  mode='markers', legendgroup="group2",  marker_symbol='star', name='Mean DYM 1 Vedsted-1', marker=dict(color='#1f78b4',size=15)))
fig.add_trace(go.Scatter(y = np.array(1536.2), x = Mean_10_LISA,  mode='markers', legendgroup="group2",  marker_symbol='star', name='Mean DYM 10 Gassum-1', marker=dict(color='#B22222',size=15)))
fig.add_trace(go.Scatter(y = np.array(1534.5), x = Mean_11_LISA,  mode='markers', legendgroup="group2",  marker_symbol='star', name='Mean DYM 11 Gassum-1', marker=dict(color='#CD2626',size=15)))
fig.add_trace(go.Scatter(y = np.array(1574.7), x = Mean_13_LISA,  mode='markers', legendgroup="group2",  marker_symbol='star', name='Mean DYM 13 Stenlille-6', marker=dict(color='#00008B',size=15)))

# Norway
fig.add_trace(go.Scatter(x = np.array(6.19020964795148), y = np.array(2761.00), mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2461', marker=dict(color='cyan',size=15)))
fig.add_trace(go.Scatter(x = np.array(8.89442542490185), y = np.array(2761.00),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2463', marker=dict(color='cyan',size=15)))
fig.add_trace(go.Scatter(x = np.array(9.8505967711706), y = np.array(2761.00),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2464', marker=dict(color='cyan',size=15)))
fig.add_trace(go.Scatter(x = np.array(6.89943834522109), y = np.array(2725),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2466', marker=dict(color='fuchsia',size=15)))
fig.add_trace(go.Scatter(x = np.array(9.48724271402332), y = np.array(2725),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2467', marker=dict(color='fuchsia',size=15)))
fig.add_trace(go.Scatter(x = np.array(10.472512403918), y = np.array(2725),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2469', marker=dict(color='fuchsia',size=15)))
fig.add_trace(go.Scatter(x = np.array(15.9042519867918), y = np.array(2680.25),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2470', marker=dict(color='lime',size=15)))
fig.add_trace(go.Scatter(x = np.array(17.2006701104299), y = np.array(2680.25),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2472', marker=dict(color='lime',size=15)))
fig.add_trace(go.Scatter(x = np.array(18.2118043148579), y = np.array(2680.25),  mode='markers', legendgroup="group3", marker_symbol='triangle-up', name='T2476', marker=dict(color='lime',size=15)))


## Data from papers
fig.add_trace(go.Scatter(x = np.array(7.5), y = np.array(4800), mode='markers', legendgroup="group4", marker_symbol='circle-x-open', name='Rotliegend G. DE (Haug,C.)', marker=dict(color='#9e0142',size=15)))
fig.add_trace(go.Scatter(x = np.array(26), y = np.array(2100),  mode='markers', legendgroup="group4", marker_symbol='circle-x-open', name='Rotliegend G. NL (Orlic, B.)', marker=dict(color='#5e4fa2',size=15)))
fig.add_trace(go.Scatter(x = np.array(26), y = np.array(3500),  mode='markers', legendgroup="group4", marker_symbol='circle-x-open', name='Bunter Fm. NL (Orlic, B.)', marker=dict(color='#01665e',size=15)))
fig.add_trace(go.Scatter(x = np.array(18), y = np.array(2260),  mode='markers', legendgroup="group4", marker_symbol='circle-x-open', name='Rotliegend G. NL (Orlic, B.)', marker=dict(color='#006837',size=15)))
fig.add_trace(go.Scatter(x = np.array(15.9), y = np.array(2570),  mode='markers', legendgroup="group4", marker_symbol='circle-x-open', name='Rotliegend G. NL (Schutte)', marker=dict(color='#542788',size=15)))
fig.add_trace(go.Scatter(x = np.array(16.2), y = np.array(2500),  mode='markers', legendgroup="group4", marker_symbol='circle-x-open', name='Captain Fm. UK (Shell)', marker=dict(color='#7f3b08',size=15)))
fig.add_trace(go.Scatter(x = np.array(12.5), y = np.array(1300),  mode='markers', legendgroup="group4", marker_symbol='circle-x-open', name='Bunter Fm. UK (Shell)', marker=dict(color='#8e0152',size=15)))
fig.add_trace(go.Scatter(x = np.array(15), y = np.array(4000),  mode='markers', legendgroup="group4", marker_symbol='circle-x-open', name='Fulmar Fm. UK (Staples)', marker=dict(color='#fdae61',size=15)))
# fig.add_trace(go.Scatter(x = np.array(2.5), y = np.array(2500),  mode='markers', legendgroup="group4", marker_symbol='circle', name='Draupne Fm. NW (Mondol)', marker=dict(color='black',size=15)))
# fig.add_trace(go.Scatter(x = np.array(5), y = np.array(2580),  mode='markers', legendgroup="group4", marker_symbol='circle', name='Drake Fm. NW (Thompson)', marker=dict(color='black',size=15)))



fig.update_layout(template="simple_white", autosize=False, width=1100, height=1200, yaxis = dict(autorange="reversed"),
    # title="Comparative of Static Youngs modulus",
    xaxis_title="Youngs modulus (GPa)",
    yaxis_title="Depth (m)",
    font=dict(
        family="New Times Roman",
        size=30,
        color="Black"
    ),
    legend=dict(title=None, orientation='v', y=0.5, yanchor="middle", x=1.3, xanchor="right", font=dict(size = 16), bordercolor='black', borderwidth=0)
)
fig.update_layout(legend_title_text = '<b>TNO acoustic data<b>',
                    legend_tracegroupgap= 20)
fig.add_annotation(xref='paper', yref='paper',
                        x=1.19, y=0.945,
                        text='<b>German samples<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=20,
        color="Black"
    ))
fig.add_annotation(xref='paper', yref='paper',
                        x=1.175, y=0.58,
                        text='<b>Danish samples<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=20,
        color="Black"
    ))
fig.add_annotation(xref='paper', yref='paper',
                        x=1.22, y=0.285,
                        text='<b>Norwegian samples<b>',
                        showarrow=False,
                        font=dict(
        family="New Times Roman",
        size=20,
        color="Black"
    ))
# fig.add_annotation(xref='paper', yref='paper',
#                         x=1.20, y=0.21,
#                         text='<b>Literature review<b>',
#                         showarrow=False,
#                         font=dict(
#         family="New Times Roman",
#         size=20,
#         color="Black"
#     ))

fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)

fig.show()
# fig.write_html("Comparative/Depth-YoungsM.html")
